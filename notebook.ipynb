# %%
import sqlite3

# verificando se os nomes dos arquivos de cache foram salvos no banco

bd_path = ".intpy/intpy.db"

conn: sqlite3.Connection = sqlite3.connect(bd_path)

cursor = conn.execute("SELECT * FROM CACHE")

for res in cursor.fetchall():
    print(res)
